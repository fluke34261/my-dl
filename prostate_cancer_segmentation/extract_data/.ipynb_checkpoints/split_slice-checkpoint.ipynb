# %%
import nibabel as nib
import numpy as np
import glob as glob

# %%
def readNifti(nifti_file):
    img = nib.load(nifti_file)
    return img.get_fdata()

# %%
def saveNifti(extract_path, numpy_array, file_name):
    ni_img = nib.Nifti1Image(numpy_array, affine=np.eye(4))
    
    file_name_nii = extract_path  + file_name + ".nii.gz"
    nib.save(ni_img, file_name_nii)

# %%
def getNiftiName(path ,nifti_file):
    return nifti_file.replace(path, "").replace(".nii.gz", "")

# %%
def main(type_data):
    root_extract = '../extract_data/'
    input_path = root_extract + type_data + '/'
    
    each_type_path = 'each_' + type_data
    extract_path = root_extract + each_type_path + '/'
    
    nifti_lists = sorted(glob.glob(input_path + '*'))
    
    for nifti in nifti_lists:
        img = readNifti(nifti)
        file_name = getNiftiName(input_path, nifti)

        for index_img_slice in range(img.shape[2]):
            slice_with_index = file_name + '_' + str(index_img_slice)
            saveNifti(
                        extract_path, 
                        img[:,:, index_img_slice], 
                        slice_with_index
                     )
            
    print(type_data + "done")

# %%
main('images')
# Out:
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ../extract_data/each_images/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 main('images')
#
# Cell In[24], line 11, in main(type_data)
#       8 nifti_lists = sorted(glob.glob(input_path + '*'))
#      10 for nifti in nifti_lists:
# ---> 11     img = readNifti(nifti)
#      12     file_name = getNiftiName(input_path, nifti)
#      14     for index_img_slice in range(img.shape[2]):
#
# Cell In[2], line 3, in readNifti(nifti_file)
#       1 def readNifti(nifti_file):
#       2     img = nib.load(nifti_file)
# ----> 3     return img.get_fdata()
#
# File ~/.local/lib/python3.10/site-packages/nibabel/dataobj_images.py:373, in DataobjImage.get_fdata(self, caching, dtype)
#     369         return self._fdata_cache
#     370 # Always return requested data type
#     371 # For array proxies, will attempt to confine data array to dtype
#     372 # during scaling
# --> 373 data = np.asanyarray(self._dataobj, dtype=dtype)
#     374 if caching == 'fill':
#     375     self._fdata_cache = data
#
# File ~/.local/lib/python3.10/site-packages/nibabel/arrayproxy.py:439, in ArrayProxy.__array__(self, dtype)
#     418 def __array__(self, dtype=None):
#     419     """Read data from file and apply scaling, casting to ``dtype``
#     420
#     421     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)
#     437         Scaled image data with type `dtype`.
#     438     """
# --> 439     arr = self._get_scaled(dtype=dtype, slicer=())
#     440     if dtype is not None:
#     441         arr = arr.astype(dtype, copy=False)
#
# File ~/.local/lib/python3.10/site-packages/nibabel/arrayproxy.py:406, in ArrayProxy._get_scaled(self, dtype, slicer)
#     404     scl_inter = scl_inter.astype(use_dtype)
#     405 # Read array and upcast as necessary for big slopes, intercepts
# --> 406 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     407 if dtype is not None:
#     408     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~/.local/lib/python3.10/site-packages/nibabel/arrayproxy.py:376, in ArrayProxy._get_unscaled(self, slicer)
#     372 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     373     (), self._shape, False
#     374 ):
#     375     with self._get_fileobj() as fileobj, self._lock:
# --> 376         return array_from_file(
#     377             self._shape,
#     378             self._dtype,
#     379             fileobj,
#     380             offset=self._offset,
#     381             order=self.order,
#     382             mmap=self._mmap,
#     383         )
#     384 with self._get_fileobj() as fileobj:
#     385     return fileslice(
#     386         fileobj,
#     387         slicer,
#    (...)
#     392         lock=self._lock,
#     393     )
#
# File ~/.local/lib/python3.10/site-packages/nibabel/volumeutils.py:465, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     463 if hasattr(infile, 'readinto'):
#     464     data_bytes = bytearray(n_bytes)
# --> 465     n_read = infile.readinto(data_bytes)
#     466     needs_copy = False
#     467 else:
#
# File /usr/lib/python3.10/gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File /usr/lib/python3.10/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /usr/lib/python3.10/gzip.py:496, in _GzipReader.read(self, size)
#     493 # Read a chunk of data from the file
#     494 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 496 uncompress = self._decompressor.decompress(buf, size)
#     497 if self._decompressor.unconsumed_tail != b"":
#     498     self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
main('labels')
